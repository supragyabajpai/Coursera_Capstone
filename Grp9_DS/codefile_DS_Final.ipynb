# %% [markdown]
# <a href="https://colab.research.google.com/github/supragyabajpai/Coursera_Capstone/blob/master/Grp9_DS/codefile_DS_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the dataset from the local host
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce74008d-c5b1-4216-86f8-cb64ab84ac85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce74008d-c5b1-4216-86f8-cb64ab84ac85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns

# %%
#importing all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df =pd.read_csv('spotify_data.csv')
df.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
df.info()
df.shape()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159764 non-null  object
#  2   track_name        1159764 non-null  object
#  3   track_id          1159764 non-null  object
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  object
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0  artist_name track_name                track_id  \
# count   1.159764e+06      1159764    1159764                 1159764
# unique           NaN        64159     882361                 1159764
# top              NaN  Traditional      Intro  53QF56cjZA9RTuuMZDrSA6
# freq             NaN         4058        466                       1
# mean    6.590613e+05          NaN        NaN                     NaN
# std     4.285492e+05          NaN        NaN                     NaN
# min     0.000000e+00          NaN        NaN                     NaN
# 25%     2.899408e+05          NaN        NaN                     NaN
# 50%     5.798815e+05          NaN        NaN                     NaN
# 75%     1.031689e+06          NaN        NaN                     NaN
# max     1.473395e+06          NaN        NaN                     NaN
#
#           popularity          year        genre  danceability        energy  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 19 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   artist_name       1159764 non-null  object
#  1   track_name        1159764 non-null  object
#  2   track_id          1159764 non-null  object
#  3   popularity        1159764 non-null  int64
#  4   year              1159764 non-null  int64
#  5   genre             1159764 non-null  object
#  6   danceability      1159764 non-null  float64
#  7   energy            1159764 non-null  float64
#  8   key               1159764 non-null  int64
#  9   loudness          1159764 non-null  float64
#  10  mode              1159764 non-null  int64
#  11  speechiness       1159764 non-null  float64
#  12  acousticness      1159764 non-null  float64
#  13  instrumentalness  1159764 non-null  float64
#  14  liveness          1159764 non-null  float64
# ...

# %% [markdown]
# Data Distribution

# %%
print("Count of unique artist:",df['artist_name'].nunique())
print("Count of unique track_name:",df['track_name'].nunique())
print("Count of unique track_id:",df['track_id'].nunique())
print("Count of unique genre:",df['genre'].nunique())
# Out:
# Count of unique artist: 64159
# Count of unique track_name: 882361
# Count of unique track_id: 1159764
# Count of unique genre: 82

# %%
sns.boxplot(df["popularity"])
# Out:
# <Axes: >

# %%
df[df['popularity']> 100]
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, track_id, popularity, year, genre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []

# %%
sns.boxplot(df["year"])
# Out:
# <Axes: >

# %%
ax=sns.histplot(df["year"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-20-008ced37ac78>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(1995.0, 0, '1995'),
#  Text(2000.0, 0, '2000'),
#  Text(2005.0, 0, '2005'),
#  Text(2010.0, 0, '2010'),
#  Text(2015.0, 0, '2015'),
#  Text(2020.0, 0, '2020'),
#  Text(2025.0, 0, '2025')]

# %%
ax=sns.histplot(df["genre"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-24-9e2a0b4f11af>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(0, 0, 'acoustic'),
#  Text(1, 0, 'afrobeat'),
#  Text(2, 0, 'alt-rock'),
#  Text(3, 0, 'ambient'),
#  Text(4, 0, 'black-metal'),
#  Text(5, 0, 'blues'),
#  Text(6, 0, 'breakbeat'),
#  Text(7, 0, 'cantopop'),
#  Text(8, 0, 'chicago-house'),
#  Text(9, 0, 'chill'),
#  Text(10, 0, 'classical'),
#  Text(11, 0, 'club'),
#  Text(12, 0, 'comedy'),
#  Text(13, 0, 'country'),
#  Text(14, 0, 'dance'),
#  Text(15, 0, 'dancehall'),
#  Text(16, 0, 'death-metal'),
#  Text(17, 0, 'deep-house'),
#  Text(18, 0, 'detroit-techno'),
#  Text(19, 0, 'disco'),
#  Text(20, 0, 'drum-and-bass'),
#  Text(21, 0, 'dub'),
#  Text(22, 0, 'dubstep'),
#  Text(23, 0, 'edm'),
#  Text(24, 0, 'electro'),
#  Text(25, 0, 'electronic'),
#  Text(26, 0, 'emo'),
#  Text(27, 0, 'folk'),
#  Text(28, 0, 'forro'),
#  Text(29, 0, 'french'),
# ...

# %%
top_ten_genres = df['genre'].value_counts().nlargest(10).index.tolist()

# %%
print(top_ten_genres)
# Out:
# ['black-metal', 'gospel', 'ambient', 'acoustic', 'alt-rock', 'emo', 'indian', 'k-pop', 'new-age', 'blues']

# %%
sns.boxplot(df["danceability"])
# Out:
# <Axes: >

# %%
ax=sns.histplot(df["energy"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-46-ebfc0b1ed70e>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(-0.2, 0, '−0.2'),
#  Text(0.0, 0, '0.0'),
#  Text(0.2, 0, '0.2'),
#  Text(0.4000000000000001, 0, '0.4'),
#  Text(0.6000000000000001, 0, '0.6'),
#  Text(0.8, 0, '0.8'),
#  Text(1.0000000000000002, 0, '1.0'),
#  Text(1.2000000000000002, 0, '1.2')]

# %%
ax=sns.histplot(df["key"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-45-212cb9a3febe>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(-2.0, 0, '−2'),
#  Text(0.0, 0, '0'),
#  Text(2.0, 0, '2'),
#  Text(4.0, 0, '4'),
#  Text(6.0, 0, '6'),
#  Text(8.0, 0, '8'),
#  Text(10.0, 0, '10'),
#  Text(12.0, 0, '12')]

# %%
sns.boxplot(df["loudness"])
# Out:
# <Axes: >

# %%
ax=sns.histplot(df["speechiness"])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# <ipython-input-50-68ec950dc9eb>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(-0.2, 0, '−0.2'),
#  Text(0.0, 0, '0.0'),
#  Text(0.2, 0, '0.2'),
#  Text(0.4000000000000001, 0, '0.4'),
#  Text(0.6000000000000001, 0, '0.6'),
#  Text(0.8, 0, '0.8'),
#  Text(1.0000000000000002, 0, '1.0'),
#  Text(1.2000000000000002, 0, '1.2')]
